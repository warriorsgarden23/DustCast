# %%
import pandas as pd

file_path = r"Z:\Thesis\Data\Met\ERA5_parquet_test\1985\Saudi_Arabia\pressure\1985_Saudi_Arabia_pressure_u_component_of_wind.parquet"

try:
    df = pd.read_parquet(file_path)
    print(f"Successfully loaded file: {file_path}")
    print(f"Columns: {df.columns.tolist()}")
except Exception as e:
    print(f"Error loading file: {file_path}")
    print(e)
# Out:
# Successfully loaded file: Z:\Thesis\Data\Met\ERA5_parquet_test\1985\Saudi_Arabia\pressure\1985_Saudi_Arabia_pressure_u_component_of_wind.parquet
# Columns: ['time', 'level', 'latitude', 'longitude', 'number', 'expver', 'u']
